# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mortality_missing_values.csv')
df2 = pd.read_csv('president_polls_2016.csv')

# %%
df
# Out:
#        Year     AgeGroup  DeathRate
# 0    1900.0  01-04 Years     1983.8
# 1       NaN  01-04 Years     1695.0
# 2    1902.0  01-04 Years        NaN
# 3    1903.0  01-04 Years     1542.1
# 4       NaN  01-04 Years        NaN
# ..      ...          ...        ...
# 471  2014.0  15-19 Years       45.5
# 472  2015.0  15-19 Years       48.3
# 473  2016.0  15-19 Years       51.2
# 474  2017.0  15-19 Years       51.5
# 475  2018.0  15-19 Years       49.2
#
# [476 rows x 3 columns]

# %%
df.head(10)
# Out:
#      Year     AgeGroup  DeathRate
# 0  1900.0  01-04 Years     1983.8
# 1     NaN  01-04 Years     1695.0
# 2  1902.0  01-04 Years        NaN
# 3  1903.0  01-04 Years     1542.1
# 4     NaN  01-04 Years        NaN
# 5  1905.0  01-04 Years     1498.9
# 6     NaN  01-04 Years        NaN
# 7  1907.0  01-04 Years        NaN
# 8  1908.0  01-04 Years     1396.8
# 9  1909.0  01-04 Years     1348.9

# %%
df.tail(10)
# Out:
#        Year     AgeGroup  DeathRate
# 466  2009.0  15-19 Years       51.9
# 467  2010.0  15-19 Years       49.4
# 468  2011.0  15-19 Years       48.9
# 469  2012.0  15-19 Years       47.2
# 470  2013.0  15-19 Years       44.8
# 471  2014.0  15-19 Years       45.5
# 472  2015.0  15-19 Years       48.3
# 473  2016.0  15-19 Years       51.2
# 474  2017.0  15-19 Years       51.5
# 475  2018.0  15-19 Years       49.2

# %%
df.isna().any()
# Out:
# Year          True
# AgeGroup     False
# DeathRate     True
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       473 non-null    float64
#  1   AgeGroup   476 non-null    object
#  2   DeathRate  472 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 11.3+ KB

# %%
df.nunique()
# Out:
# Year         119
# AgeGroup       4
# DeathRate    426
# dtype: int64

# %%
sns.boxplot(df['DeathRate'])
plt.show()
sns.boxplot(df['Year'])
plt.show()

# %%
df2.columns
# Out:
# Index(['cycle', 'branch', 'type', 'matchup', 'forecastdate', 'state',
#        'startdate', 'enddate', 'pollster', 'grade', 'samplesize', 'population',
#        'poll_wt', 'rawpoll_clinton', 'rawpoll_trump', 'rawpoll_johnson',
#        'rawpoll_mcmullin', 'adjpoll_clinton', 'adjpoll_trump',
#        'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions', 'url',
#        'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %% [markdown]
# ### Rename Columns:
# 1. rawpoll_clinton -> clinton_believers_pc
# 2. rawpoll_trump -> trump_believers_pc
# 3. rawpoll_johnson -> johnson_believers_pc
# 4. rawpoll_mcmullin -> mcmullin_believers_pc

# %%
df2.rename({
    'rawpoll_clinton' : 'clinton_believers_pc',
    'rawpoll_trump' : 'trump_believers_pc',
    'rawpoll_johnson' : 'johnson_believers_pc',
    'rawpoll_mcmullin' : 'mcmullin_believers_pc'
}, inplace = True)

# %%
df2.head()
# Out:
#    cycle     branch        type                        matchup forecastdate  \
# 0   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
#
#   state  startdate    enddate                  pollster grade  ...  \
# 0  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+  ...
# 1  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B  ...
# 2  U.S.  11/2/2016  11/6/2016                     Ipsos    A-  ...
# 3  U.S.  11/4/2016  11/7/2016                    YouGov     B  ...
# 4  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-  ...
#
#    adjpoll_clinton adjpoll_trump  adjpoll_johnson  adjpoll_mcmullin  \
# ...

# %%
df2.shape
# Out:
# (12624, 27)

# %%
df2.nunique()
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %%
df2.drop(['cycle', 'branch', 'matchup', 'forecastdate', 'multiversions'], axis = 1, inplace = True)

# %%
df2.head()
# Out:
#          type state  startdate    enddate                  pollster grade  \
# 0  polls-plus  U.S.  11/3/2016  11/6/2016  ABC News/Washington Post    A+
# 1  polls-plus  U.S.  11/1/2016  11/7/2016   Google Consumer Surveys     B
# 2  polls-plus  U.S.  11/2/2016  11/6/2016                     Ipsos    A-
# 3  polls-plus  U.S.  11/4/2016  11/7/2016                    YouGov     B
# 4  polls-plus  U.S.  11/3/2016  11/6/2016          Gravis Marketing    B-
#
#    samplesize population   poll_wt  rawpoll_clinton  ...  rawpoll_mcmullin  \
# 0      2220.0         lv  8.720654            47.00  ...               NaN
# 1     26574.0         lv  7.628472            38.03  ...               NaN
# 2      2195.0         lv  6.424334            42.00  ...               NaN
# 3      3677.0         lv  6.087135            45.00  ...               NaN
# 4     16639.0         rv  5.316449            47.00  ...               NaN
#
# ...

# %%
df2.shape
# Out:
# (12624, 22)

# %% [markdown]
# ### Dictionaries in Python:

# %%
dict_1 = {
    'Ontario' : 'Toronto',
    'BC' : 'Vancouver',
    'Manitoba' : 'Winnipeg'
}
dict_1
# Out:
# {'Ontario': 'Toronto', 'BC': 'Vancouver', 'Manitoba': 'Winnipeg'}

# %%
for key, value in dict_1.items():
    print(f'{ key } -> { value }')
# Out:
# Ontario -> Toronto
# BC -> Vancouver
# Manitoba -> Winnipeg

# %%
for value in dict_1.values():
    print(value)
# Out:
# Toronto
# Vancouver
# Winnipeg

# %%
for key in dict_1.keys():
    print(key)
# Out:
# Ontario
# BC
# Manitoba

# %%
dict_2 = {
    'Ontario' : ['Toronto', 'North York', 'Scarborough', 'Belleville', 'Brampton', 'Hamilton', 'Mississauga'],
    'BC' : ['Vancouver', 'Vernon'],
    'Manitoba' : ['Winnipeg', 'Brandon']
}
dict_2
# Out:
# {'Ontario': ['Toronto',
#   'North York',
#   'Scarborough',
#   'Belleville',
#   'Brampton',
#   'Hamilton',
#   'Mississauga'],
#  'BC': ['Vancouver', 'Vernon'],
#  'Manitoba': ['Winnipeg', 'Brandon']}

# %%
for key, value in dict_2.items():
    print(f'{ key } -> { value }')
# Out:
# Ontario -> ['Toronto', 'North York', 'Scarborough', 'Belleville', 'Brampton', 'Hamilton', 'Mississauga']
# BC -> ['Vancouver', 'Vernon']
# Manitoba -> ['Winnipeg', 'Brandon']

# %%
for _, value in dict_2.items():
    for v in value:
        print(v)
    print()
# Out:
# Toronto
# North York
# Scarborough
# Belleville
# Brampton
# Hamilton
# Mississauga
#
# Vancouver
# Vernon
#
# Winnipeg
# Brandon

# %%
df2.columns
# Out:
# Index(['type', 'state', 'startdate', 'enddate', 'pollster', 'grade',
#        'samplesize', 'population', 'poll_wt', 'rawpoll_clinton',
#        'rawpoll_trump', 'rawpoll_johnson', 'rawpoll_mcmullin',
#        'adjpoll_clinton', 'adjpoll_trump', 'adjpoll_johnson',
#        'adjpoll_mcmullin', 'url', 'poll_id', 'question_id', 'createddate',
#        'timestamp'],
#       dtype='object')

# %%
cols = ['state', 'startdate', 'enddate', 'pollster']
df2[cols]
# Out:
#                state   startdate    enddate                     pollster
# 0               U.S.   11/3/2016  11/6/2016     ABC News/Washington Post
# 1               U.S.   11/1/2016  11/7/2016      Google Consumer Surveys
# 2               U.S.   11/2/2016  11/6/2016                        Ipsos
# 3               U.S.   11/4/2016  11/7/2016                       YouGov
# 4               U.S.   11/3/2016  11/6/2016             Gravis Marketing
# ...              ...         ...        ...                          ...
# 12619  New Hampshire    7/9/2016  7/18/2016  University of New Hampshire
# 12620      Wisconsin  10/21/2016  11/2/2016                        Ipsos
# 12621       New York    8/7/2016  8/10/2016                Siena College
# 12622       Virginia   9/30/2016  10/6/2016                        Ipsos
# 12623      Wisconsin    6/9/2016  6/12/2016         Marquette University
#
# [12624 rows x 4 columns]

# %% [markdown]
# # Dealing with Missing Values:

# %%
df2.isna().any()
# Out:
# type                False
# state               False
# startdate           False
# enddate             False
# pollster            False
# grade                True
# samplesize           True
# population          False
# poll_wt             False
# rawpoll_clinton     False
# rawpoll_trump       False
# rawpoll_johnson      True
# rawpoll_mcmullin     True
# adjpoll_clinton     False
# adjpoll_trump       False
# adjpoll_johnson      True
# adjpoll_mcmullin     True
# url                  True
# poll_id             False
# question_id         False
# createddate         False
# timestamp           False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       473 non-null    float64
#  1   AgeGroup   476 non-null    object
#  2   DeathRate  472 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 11.3+ KB

# %%
df.head()
# Out:
#      Year     AgeGroup  DeathRate
# 0  1900.0  01-04 Years     1983.8
# 1     NaN  01-04 Years     1695.0
# 2  1902.0  01-04 Years        NaN
# 3  1903.0  01-04 Years     1542.1
# 4     NaN  01-04 Years        NaN

# %%
df.shape
# Out:
# (476, 3)

# %%
df.isna().any()
# Out:
# Year          True
# AgeGroup     False
# DeathRate     True
# dtype: bool

# %%
df.isnull()
# Out:
#       Year  AgeGroup  DeathRate
# 0    False     False      False
# 1     True     False      False
# 2    False     False       True
# 3    False     False      False
# 4     True     False       True
# ..     ...       ...        ...
# 471  False     False      False
# 472  False     False      False
# 473  False     False      False
# 474  False     False      False
# 475  False     False      False
#
# [476 rows x 3 columns]

# %%
df.isnull().any()
# Out:
# Year          True
# AgeGroup     False
# DeathRate     True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Year         3
# AgeGroup     0
# DeathRate    4
# dtype: int64

# %%
df.describe()
# Out:
#               Year    DeathRate
# count   473.000000   472.000000
# mean   1959.350951   181.221186
# std      34.210953   265.215427
# min    1900.000000    11.400000
# 25%    1930.000000    40.500000
# 50%    1959.000000    88.400000
# 75%    1989.000000   219.675000
# max    2018.000000  1983.800000

# %%
print(len(df) - df.isnull().sum())
len(df)
# Out:
# Year         473
# AgeGroup     476
# DeathRate    472
# dtype: int64
# 476

# %%
df.count()
# Out:
# Year         473
# AgeGroup     476
# DeathRate    472
# dtype: int64

# %% [markdown]
# # Change data type of field Year.

# %%
""'df['Year'] = df['Year'].astype(int)
df['Year']"''"
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['Year'] = df['Year'].astype(int)
#       2 df['Year']
#
# File E:\Softwares\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File E:\Softwares\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
# Multiple row datatype change
#df = df.astype(['Year' : int, 'DeathRate' : int])

# %%
plt.plot(df['Year'], df['DeathRate'])
plt.show()
sns.boxplot(df['DeathRate'])
plt.show()
sns.boxplot(df['Year'])
plt.show()

# %%
# Deathrates above 500:
df[df['DeathRate'] > 500]
# Out:
#        Year     AgeGroup  DeathRate
# 0    1900.0  01-04 Years     1983.8
# 1       NaN  01-04 Years     1695.0
# 3    1903.0  01-04 Years     1542.1
# 5    1905.0  01-04 Years     1498.9
# 8    1908.0  01-04 Years     1396.8
# 9    1909.0  01-04 Years     1348.9
# 10   1910.0  01-04 Years     1397.3
# 11   1911.0  01-04 Years     1176.0
# 12   1912.0  01-04 Years     1094.1
# 13   1913.0  01-04 Years     1193.4
# 14   1914.0  01-04 Years     1024.2
# 15   1915.0  01-04 Years      924.2
# 16   1916.0  01-04 Years     1111.5
# 17   1917.0  01-04 Years     1066.0
# 18   1918.0  01-04 Years     1573.5
# 19   1919.0  01-04 Years      928.0
# 20   1920.0  01-04 Years      987.2
# 21   1921.0  01-04 Years      801.2
# 22   1922.0  01-04 Years      742.0
# 23   1923.0  01-04 Years      806.7
# 24   1924.0  01-04 Years      683.2
# 25   1925.0  01-04 Years      641.0
# 26   1926.0  01-04 Years      723.4
# 27   1927.0  01-04 Years      591.0
# 28   1928.0  01-04 Years      647.5
# ...

# %%
# Sort the above rows in decreasing order of DeathRate.
df[df['DeathRate'] > 500].sort_values(by = 'DeathRate', ascending = False)
# Out:
#        Year     AgeGroup  DeathRate
# 0    1900.0  01-04 Years     1983.8
# 1       NaN  01-04 Years     1695.0
# 18   1918.0  01-04 Years     1573.5
# 3    1903.0  01-04 Years     1542.1
# 5    1905.0  01-04 Years     1498.9
# 10   1910.0  01-04 Years     1397.3
# 8    1908.0  01-04 Years     1396.8
# 9    1909.0  01-04 Years     1348.9
# 13   1913.0  01-04 Years     1193.4
# 11   1911.0  01-04 Years     1176.0
# 16   1916.0  01-04 Years     1111.5
# 12   1912.0  01-04 Years     1094.1
# 17   1917.0  01-04 Years     1066.0
# 14   1914.0  01-04 Years     1024.2
# 20   1920.0  01-04 Years      987.2
# 19   1919.0  01-04 Years      928.0
# 15   1915.0  01-04 Years      924.2
# 23   1923.0  01-04 Years      806.7
# 21   1921.0  01-04 Years      801.2
# 375  1918.0  15-19 Years      777.4
# 22   1922.0  01-04 Years      742.0
# 26   1926.0  01-04 Years      723.4
# 24   1924.0  01-04 Years      683.2
# 28   1928.0  01-04 Years      647.5
# 25   1925.0  01-04 Years      641.0
# ...

# %%
df[df['DeathRate'] > 500].sort_values(by = 'Year')
# Out:
#        Year     AgeGroup  DeathRate
# 0    1900.0  01-04 Years     1983.8
# 3    1903.0  01-04 Years     1542.1
# 5    1905.0  01-04 Years     1498.9
# 8    1908.0  01-04 Years     1396.8
# 9    1909.0  01-04 Years     1348.9
# 10   1910.0  01-04 Years     1397.3
# 11   1911.0  01-04 Years     1176.0
# 12   1912.0  01-04 Years     1094.1
# 13   1913.0  01-04 Years     1193.4
# 14   1914.0  01-04 Years     1024.2
# 15   1915.0  01-04 Years      924.2
# 16   1916.0  01-04 Years     1111.5
# 17   1917.0  01-04 Years     1066.0
# 375  1918.0  15-19 Years      777.4
# 18   1918.0  01-04 Years     1573.5
# 19   1919.0  01-04 Years      928.0
# 20   1920.0  01-04 Years      987.2
# 21   1921.0  01-04 Years      801.2
# 22   1922.0  01-04 Years      742.0
# 23   1923.0  01-04 Years      806.7
# 24   1924.0  01-04 Years      683.2
# 25   1925.0  01-04 Years      641.0
# 26   1926.0  01-04 Years      723.4
# 27   1927.0  01-04 Years      591.0
# 28   1928.0  01-04 Years      647.5
# ...

# %%
plt.plot(df[df['DeathRate'] > 500].sort_values(by = 'Year')['Year'], df[df['DeathRate'] > 500].sort_values(by = 'Year')['DeathRate'])

# %%
# Display those rows for the ageGroup of 15-19 years.
df[df['AgeGroup'] == '15-19 Years'].sort_values(by = 'Year')

# %%
plt.plot(df[df['AgeGroup'] == '15-19 Years'].sort_values(by = 'Year')['Year'], df[df['AgeGroup'] == '15-19 Years'].sort_values(by = 'Year')['DeathRate'])

# %%
# Working on the AgeGroup - 15-19 Years.
teen_df = df[df['AgeGroup'] == '15-19 Years'].sort_values(by = 'Year')
teen_df
# Out:
#        Year     AgeGroup  DeathRate
# 357  1900.0  15-19 Years      484.8
# 358  1901.0  15-19 Years      454.4
# 359  1902.0  15-19 Years      421.5
# 360  1903.0  15-19 Years      434.1
# 361  1904.0  15-19 Years      471.4
# ..      ...          ...        ...
# 471  2014.0  15-19 Years       45.5
# 472  2015.0  15-19 Years       48.3
# 473  2016.0  15-19 Years       51.2
# 474  2017.0  15-19 Years       51.5
# 475  2018.0  15-19 Years       49.2
#
# [119 rows x 3 columns]

# %%
teen_df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 teen_df.describe()
#
# NameError: name 'teen_df' is not defined

# %%
teen_df[teen_df['DeathRate'] > 500]

# %%
teen_df.plot(x = 'Year', y = 'DeathRate')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # How to fix outliers:

# %%
# Using mean value, we are going to fix the outlier.
teen_df['DeathRate'].mean()
# Out:
# 177.3747899159664

# %%
# Replacing the mean value with the outlier.
print(teen_df[teen_df['DeathRate'] > 500]) # Before.
#teen_df[teen_df['DeathRate'] > 500]['DeathRate'] = teen_df['DeathRate'].mean() # Should work but not correct syntax.
teen_df.loc[teen_df['DeathRate'] > 500,'DeathRate'] = teen_df['DeathRate'].mean()
teen_df[teen_df['DeathRate'] > 500] # After.
# Out:
#        Year     AgeGroup  DeathRate
# 375  1918.0  15-19 Years      777.4
# Empty DataFrame
# Columns: [Year, AgeGroup, DeathRate]
# Index: []

# %%
teen_df.plot(x = 'Year', y = 'DeathRate')
# Out:
# <Axes: xlabel='Year'>
