# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('president_polls_2016.csv')
df
# Out:
#        cycle     branch        type                        matchup  \
# 0       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 1       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 2       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 3       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# 4       2016  President  polls-plus  Clinton vs. Trump vs. Johnson
# ...      ...        ...         ...                            ...
# 12619   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12620   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12621   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12622   2016  President  polls-only  Clinton vs. Trump vs. Johnson
# 12623   2016  President  polls-only  Clinton vs. Trump vs. Johnson
#
#       forecastdate          state   startdate    enddate  \
# 0          11/8/16           U.S.   11/3/2016  11/6/2016
# ...

# %%
df.isna().any()
# Out:
# cycle               False
# branch              False
# type                False
# matchup             False
# forecastdate        False
# state               False
# startdate           False
# enddate             False
# pollster            False
# grade                True
# samplesize           True
# population          False
# poll_wt             False
# rawpoll_clinton     False
# rawpoll_trump       False
# rawpoll_johnson      True
# rawpoll_mcmullin     True
# adjpoll_clinton     False
# adjpoll_trump       False
# adjpoll_johnson      True
# adjpoll_mcmullin     True
# multiversions        True
# url                  True
# poll_id             False
# question_id         False
# createddate         False
# timestamp           False
# dtype: bool

# %%
df.shape
# Out:
# (12624, 27)

# %%
df.columns
# Out:
# Index(['cycle', 'branch', 'type', 'matchup', 'forecastdate', 'state',
#        'startdate', 'enddate', 'pollster', 'grade', 'samplesize', 'population',
#        'poll_wt', 'rawpoll_clinton', 'rawpoll_trump', 'rawpoll_johnson',
#        'rawpoll_mcmullin', 'adjpoll_clinton', 'adjpoll_trump',
#        'adjpoll_johnson', 'adjpoll_mcmullin', 'multiversions', 'url',
#        'poll_id', 'question_id', 'createddate', 'timestamp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12624 entries, 0 to 12623
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   cycle             12624 non-null  int64
#  1   branch            12624 non-null  object
#  2   type              12624 non-null  object
#  3   matchup           12624 non-null  object
#  4   forecastdate      12624 non-null  object
#  5   state             12624 non-null  object
#  6   startdate         12624 non-null  object
#  7   enddate           12624 non-null  object
#  8   pollster          12624 non-null  object
#  9   grade             11337 non-null  object
#  10  samplesize        12621 non-null  float64
#  11  population        12624 non-null  object
#  12  poll_wt           12624 non-null  float64
#  13  rawpoll_clinton   12624 non-null  float64
#  14  rawpoll_trump     12624 non-null  float64
#  15  rawpoll_johnson   8397 non-null   float64
# ...

# %%
df.describe()
# Out:
#          cycle    samplesize       poll_wt  rawpoll_clinton  rawpoll_trump  \
# count  12624.0  12621.000000  12624.000000     12624.000000   12624.000000
# mean    2016.0   1148.216068      0.255431        41.990860      39.828710
# std        0.0   2630.647790      0.669326         7.727792       7.877327
# min     2016.0     35.000000      0.000000        11.040000       4.000000
# 25%     2016.0    447.000000      0.000358        38.000000      35.000000
# 50%     2016.0    772.000000      0.008172        43.000000      40.000000
# 75%     2016.0   1237.000000      0.086735        46.200000      45.000000
# max     2016.0  84292.000000      8.720654        88.000000      68.000000
#
#        rawpoll_johnson  rawpoll_mcmullin  adjpoll_clinton  adjpoll_trump  \
# count      8397.000000         90.000000     12624.000000   12624.000000
# mean          7.381740         24.004000        43.323005      42.667719
# ...

# %% [markdown]
# ### Missing values in various fields:
# 1. 'samplesize'
# 2. 'grade'
#
# <hr>
#
# ### Should be 'datetime' in:
# 1. 'forecastdate'
# 2. 'startdate'
# 3. 'enddate'
# 4. 'createddate'
# 5. 'timestamp'

# %%
df.head(20)
# Out:
#     cycle     branch        type                        matchup forecastdate  \
# 0    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 1    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 2    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 3    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 4    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 5    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 6    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 7    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 8    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 9    2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# 10   2016  President  polls-plus  Clinton vs. Trump vs. Johnson      11/8/16
# ...

# %% [markdown]
# <html>
#     <head>
#         <title>HTML in Jupyter Notebook</title>
#         <style>
#             table
#             {
#                 background-color: #333;
#                 color: #FFF;
#                 border: 10px solid #333;
#             }
#         </style>
#     </head>
#     <body>
#         <table>
#             <tr>
#                 <td>Rajat</td>
#                 <td>Meet</td>
#                 <td>Tanmay</td>
#                 <td>Rachit</td>
#                 <td>Puneet</td>
#             </tr>
#             <tr>
#                 <td>Sakshi</td>
#                 <td>Akshita</td>
#                 <td>Nishit</td>
#                 <td>Aliyu</td>
#                 <td>Simon</td>
#             </tr>
#             <tr>
#                 <td>Hetal</td>
#                 <td>Ruchitaben</td>
#                 <td>Harsh</td>
#             </tr>
#         </table>
#     </body>
# </html>

# %%
df[['cycle', 'branch', 'forecastdate']].head()
# Out:
#    cycle     branch forecastdate
# 0   2016  President      11/8/16
# 1   2016  President      11/8/16
# 2   2016  President      11/8/16
# 3   2016  President      11/8/16
# 4   2016  President      11/8/16

# %%
# Find a number of unique values in a series.
df['cycle'].nunique()
# Out:
# 1

# %%
# Find list of unique values in a series.
df['cycle'].unique()
# Out:
# array([2016], dtype=int64)

# %%
df['grade'].nunique()
# Out:
# 10

# %%
df['grade'].unique()
# Out:
# array(['A+', 'B', 'A-', 'B-', 'A', nan, 'B+', 'C+', 'C-', 'C', 'D'],
#       dtype=object)

# %%
df.nunique()
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %%
df[['cycle', 'branch', 'forecastdate']].nunique()
# Out:
# cycle           1
# branch          1
# forecastdate    1
# dtype: int64

# %%
df[['grade', 'state']].head(10)
# Out:
#   grade       state
# 0    A+        U.S.
# 1     B        U.S.
# 2    A-        U.S.
# 3     B        U.S.
# 4    B-        U.S.
# 5     A        U.S.
# 6    A-        U.S.
# 7    A-        U.S.
# 8   NaN  New Mexico
# 9    A-        U.S.

# %%
df['branch'].nunique()
# Out:
# 1

# %%
df['branch'].unique()
# Out:
# array(['President'], dtype=object)

# %%
df['state'].unique()
# Out:
# array(['U.S.', 'New Mexico', 'Virginia', 'Iowa', 'Wisconsin',
#        'North Carolina', 'Georgia', 'Florida', 'Oregon', 'Ohio',
#        'South Carolina', 'New York', 'Michigan', 'Pennsylvania',
#        'Missouri', 'New Hampshire', 'Arizona', 'Nevada', 'Colorado',
#        'California', 'Washington', 'Texas', 'Utah', 'Illinois', 'Indiana',
#        'Tennessee', 'Connecticut', 'Massachusetts', 'New Jersey',
#        'Kansas', 'Kentucky', 'Minnesota', 'Oklahoma', 'Maryland',
#        'Alabama', 'Nebraska', 'Louisiana', 'Maine', 'Arkansas', 'Alaska',
#        'Vermont', 'Idaho', 'Mississippi', 'West Virginia', 'South Dakota',
#        'Montana', 'Hawaii', 'Maine CD-1', 'Maine CD-2', 'Rhode Island',
#        'Nebraska CD-3', 'Nebraska CD-1', 'Delaware', 'North Dakota',
#        'District of Columbia', 'Nebraska CD-2', 'Wyoming'], dtype=object)

# %%
for col in df:
    print(f'{ col.title() }: { df[col].unique() }\n')
# Out:
# Cycle: [2016]
#
# Branch: ['President']
#
# Type: ['polls-plus' 'now-cast' 'polls-only']
#
# Matchup: ['Clinton vs. Trump vs. Johnson']
#
# Forecastdate: ['11/8/16']
#
# State: ['U.S.' 'New Mexico' 'Virginia' 'Iowa' 'Wisconsin' 'North Carolina'
#  'Georgia' 'Florida' 'Oregon' 'Ohio' 'South Carolina' 'New York'
#  'Michigan' 'Pennsylvania' 'Missouri' 'New Hampshire' 'Arizona' 'Nevada'
#  'Colorado' 'California' 'Washington' 'Texas' 'Utah' 'Illinois' 'Indiana'
#  'Tennessee' 'Connecticut' 'Massachusetts' 'New Jersey' 'Kansas'
#  'Kentucky' 'Minnesota' 'Oklahoma' 'Maryland' 'Alabama' 'Nebraska'
#  'Louisiana' 'Maine' 'Arkansas' 'Alaska' 'Vermont' 'Idaho' 'Mississippi'
#  'West Virginia' 'South Dakota' 'Montana' 'Hawaii' 'Maine CD-1'
#  'Maine CD-2' 'Rhode Island' 'Nebraska CD-3' 'Nebraska CD-1' 'Delaware'
#  'North Dakota' 'District of Columbia' 'Nebraska CD-2' 'Wyoming']
#
# Startdate: ['11/3/2016' '11/1/2016' '11/2/2016' '11/4/2016' '11/6/2016' '11/5/2016'
# ...

# %%
# Better Approach:
df.apply(pd.unique)
# Out:
# cycle                                                          [2016]
# branch                                                    [President]
# type                               [polls-plus, now-cast, polls-only]
# matchup                               [Clinton vs. Trump vs. Johnson]
# forecastdate                                                [11/8/16]
# state               [U.S., New Mexico, Virginia, Iowa, Wisconsin, ...
# startdate           [11/3/2016, 11/1/2016, 11/2/2016, 11/4/2016, 1...
# enddate             [11/6/2016, 11/7/2016, 11/5/2016, 11/4/2016, 1...
# pollster            [ABC News/Washington Post, Google Consumer Sur...
# grade                       [A+, B, A-, B-, A, nan, B+, C+, C-, C, D]
# samplesize          [2220.0, 26574.0, 2195.0, 3677.0, 16639.0, 129...
# population                                             [lv, rv, a, v]
# poll_wt             [8.720654, 7.628472, 6.424334, 6.087135, 5.316...
# ...

# %%
df[['grade', 'state']].groupby(['grade']).count()
# Out:
#        state
# grade
# A        477
# A+       252
# A-      3255
# B       3033
# B+       612
# B-       426
# C        174
# C+       987
# C-      2079
# D         42

# %%
df['state'].value_counts()
# Out:
# U.S.                    3318
# Florida                  444
# North Carolina           375
# Pennsylvania             375
# Ohio                     345
# New Hampshire            336
# Nevada                   279
# Virginia                 273
# Michigan                 258
# Wisconsin                240
# Georgia                  240
# Colorado                 240
# Arizona                  237
# California               213
# Iowa                     210
# Missouri                 204
# Utah                     198
# New York                 189
# Illinois                 180
# Texas                    174
# Indiana                  168
# New Jersey               162
# Oregon                   162
# Maine                    159
# South Carolina           156
# Washington               153
# Massachusetts            153
# New Mexico               153
# Kansas                   153
# Louisiana                150
# Kentucky                 147
# Idaho                    144
# ...

# %%
df['state'].value_counts() / len(df) * 100
# Out:
# U.S.                    26.283270
# Florida                  3.517110
# North Carolina           2.970532
# Pennsylvania             2.970532
# Ohio                     2.732890
# New Hampshire            2.661597
# Nevada                   2.210076
# Virginia                 2.162548
# Michigan                 2.043726
# Wisconsin                1.901141
# Georgia                  1.901141
# Colorado                 1.901141
# Arizona                  1.877376
# California               1.687262
# Iowa                     1.663498
# Missouri                 1.615970
# Utah                     1.568441
# New York                 1.497148
# Illinois                 1.425856
# Texas                    1.378327
# Indiana                  1.330798
# New Jersey               1.283270
# Oregon                   1.283270
# Maine                    1.259506
# South Carolina           1.235741
# Washington               1.211977
# Massachusetts            1.211977
# ...

# %%
df['state'].value_counts(normalize = True) * 100
# Out:
# U.S.                    26.283270
# Florida                  3.517110
# North Carolina           2.970532
# Pennsylvania             2.970532
# Ohio                     2.732890
# New Hampshire            2.661597
# Nevada                   2.210076
# Virginia                 2.162548
# Michigan                 2.043726
# Wisconsin                1.901141
# Georgia                  1.901141
# Colorado                 1.901141
# Arizona                  1.877376
# California               1.687262
# Iowa                     1.663498
# Missouri                 1.615970
# Utah                     1.568441
# New York                 1.497148
# Illinois                 1.425856
# Texas                    1.378327
# Indiana                  1.330798
# New Jersey               1.283270
# Oregon                   1.283270
# Maine                    1.259506
# South Carolina           1.235741
# Washington               1.211977
# Massachusetts            1.211977
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
plt.pie(df['state'].value_counts(normalize = True) * 100, labels = df['state'].value_counts(normalize = True), autopct ='%.00f%%', radius = 4)
plt.show()

# %%
df[['state', 'grade']].value_counts()
# Out:
# state          grade
# U.S.           A-       1215
#                C+        546
#                B         162
#                C-        126
#                A+        114
#                         ...
# Nebraska CD-1  B           3
# Indiana        A           3
# Nebraska CD-2  B           3
# Missouri       A           3
# Mississippi    C           3
# Length: 321, dtype: int64

# %%
plt.pie(df[['state', 'grade']].value_counts(), autopct ='%.00f%%', radius = 4)
plt.show()

# %%
#df[['state', 'grade']].groupby(['state']).count()
#df[['state', 'grade']].value_counts()
#print(df[df['state'] == 'U.S.'])
#print(df[df['grade'] == 'C-'])
#df[df['state'] == 'U.S.'].groupby('grade').agg({ 'state' : 'max' })

# %%
len(df[df['state'] == 'U.S.']['grade'] == 'C-')
# Out:
# 3318

# %%
# How many times did the state of 'U.S' received a grade of 'C-'?

# %%
(df[df['state'] == 'U.S.']['grade'] == 'C-').sum()
# Out:
# 126

# %% [markdown]
# ### Dropping Columns

# %%
df.nunique()
# Out:
# cycle                   1
# branch                  1
# type                    3
# matchup                 1
# forecastdate            1
# state                  57
# startdate             352
# enddate               345
# pollster              196
# grade                  10
# samplesize           1766
# population              4
# poll_wt              4399
# rawpoll_clinton      1312
# rawpoll_trump        1385
# rawpoll_johnson       584
# rawpoll_mcmullin       16
# adjpoll_clinton     12569
# adjpoll_trump       12582
# adjpoll_johnson      6629
# adjpoll_mcmullin       57
# multiversions           1
# url                  1304
# poll_id              4208
# question_id          4208
# createddate           222
# timestamp               3
# dtype: int64

# %%
ds = df.drop(columns = ['cycle', 'branch', 'matchup', 'forecastdate', 'multiversions'], inplace = False)

# %%
print(ds.shape)
print(df.shape)
# Out:
# (12624, 22)
# (12624, 27)
#              type          state   startdate    enddate  \
# 0      polls-plus           U.S.   11/3/2016  11/6/2016
# 1      polls-plus           U.S.   11/1/2016  11/7/2016
# 2      polls-plus           U.S.   11/2/2016  11/6/2016
# 3      polls-plus           U.S.   11/4/2016  11/7/2016
# 4      polls-plus           U.S.   11/3/2016  11/6/2016
# ...           ...            ...         ...        ...
# 12619  polls-only  New Hampshire    7/9/2016  7/18/2016
# 12620  polls-only      Wisconsin  10/21/2016  11/2/2016
# 12621  polls-only       New York    8/7/2016  8/10/2016
# 12622  polls-only       Virginia   9/30/2016  10/6/2016
# 12623  polls-only      Wisconsin    6/9/2016  6/12/2016
#
#                           pollster grade  samplesize population   poll_wt  \
# 0         ABC News/Washington Post    A+      2220.0         lv  8.720654
# 1          Google Consumer Surveys     B     26574.0         lv  7.628472
# ...
